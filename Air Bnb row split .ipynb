# %% [markdown]
# # Import libraries and data

# %%
import os
import pandas as pd
import numpy as np

all_data = pd.read_csv("Listings.csv")
all_data.head(1)
# Out:
# /Users/felixleonard/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (5,13) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#    listing_id                                            name  host_id  \
# 0      281420  Beautiful Flat in le Village Montmartre, Paris  1466919
#
#    host_since                 host_location host_response_time  \
# 0  2011-12-03  Paris, Ile-de-France, France                NaN
#
#    host_response_rate  host_acceptance_rate host_is_superhost  \
# 0                 NaN                   NaN                 f
#
#    host_total_listings_count  ... minimum_nights maximum_nights  \
# 0                        1.0  ...              2           1125
#
#   review_scores_rating review_scores_accuracy review_scores_cleanliness  \
# 0                100.0                   10.0                      10.0
#
#    review_scores_checkin  review_scores_communication review_scores_location  \
# 0                   10.0                         10.0                   10.0
#
#   review_scores_value  instant_bookable
# 0                10.0                 f
#
# [1 rows x 33 columns]

# %% [markdown]
# # Get the column amenities and delet the last character

# %%
all_data2=all_data["amenities"].str[:-1]
all_data2.head(2)
# Out:
# 0    ["Heating", "Kitchen", "Washer", "Wifi", "Long...
# 1    ["Shampoo", "Heating", "Kitchen", "Essentials"...
# Name: amenities, dtype: object

# %%
amenities= all_data2.str.split(',', expand=True)
amenities.head(1)
# Out:
#            0           1          2        3                           4   \
# 0  ["Heating"   "Kitchen"   "Washer"   "Wifi"   "Long term stays allowed"
#
#      5     6     7     8     9   ...    79    80    81    82    83    84  \
# 0  None  None  None  None  None  ...  None  None  None  None  None  None
#
#      85    86    87    88
# 0  None  None  None  None
#
# [1 rows x 89 columns]

# %%
 for i in range(89):
        amenities[i]= amenities[i].str[2:-1]
amenities.head(1)
# Out:
#         0        1       2     3                        4     5     6     7   \
# 0  Heating  Kitchen  Washer  Wifi  Long term stays allowed  None  None  None
#
#      8     9   ...    79    80    81    82    83    84    85    86    87    88
# 0  None  None  ...  None  None  None  None  None  None  None  None  None  None
#
# [1 rows x 89 columns]

# %% [markdown]
# # Get unique values in all columns and Create excel file unique values

# %%
unique_values = set()
for col in amenities:
    unique_values.update(amenities[col])
# Out:
# {'',
#  'Natural gas barbeque',
#  '4 burner stainless steel gas stove',
#  'Paid parking garage off premises \\u2013 $40 per day',
#  '40\\" HDTV with premium cable',
#  '24\\" TV',
#  'Smeg stainless steel stove',
#  'Toshiba refrigerator',
#  'Children\\u2019s books and toys for ages 0-2 years ol',
#  'Onsite bar \\u2014 Bel Ami Bar',
#  'Bath & Body Works shampoo',
#  'vegan s\\u00ecv\\u00ec sabun body soap',
#  'Ar\\u00e7el\\u0131c refrigerator',
#  'Everyone Body Soap/organic body soap',
#  '60\\" HDTV with Apple TV',
#  'Outdoor kitchen',
#  'Shikai - natural plant based shampoo',
#  'panasonic sound system',
#  'Bottled water',
#  'DeLonghi induction stove',
#  'Onkyo sound system with aux',
#  'Electrolux stainless steel induction stove',
#  'Dining area for 12 people',
#  'Bosch Electric Oven stainless steel oven',
#  'Elseve Loreal conditioner',
#  'Miss Lynn shampoo',
#  'Amana refrigerator',
#  'Miele stainless steel oven',
#  'RCA sound system',
#  'Bicycle',
#  'Waterfront',
#  'Dietrich oven',
#  'Mini Four Moulinex oven',
#  'Smeg gas stove',
#  'Wifi \\u2013 950 Mbps',
#  '3m conditioner',
#  'Onsite rooftop bar \\u2014 Bar ',
#  'brastemp frost free  refrigerator',
#  'Piano',
#  'Westinghouse refrigerator',
#  'cooktop \\u00e0 g\\u00e1s gas stove',
#  'Meditation room',
#  'Brandt gas stove',
#  '-10 years ol',
#  'sunsilk conditioner',
#  'emongrass and Jasmin-Mint Hotel fragrance selected products body soap',
#  'ega Plana',
#  'Marca stainless steel gas stove',
#  'Paid parking garage off premises \\u2013 BRL40 per day',
#  'ELETROLUX refrigerator',
#  'Pears body soap',
#  'Viking stainless steel oven',
#  'avec congelateur refrigerator',
#  'Acca Kappa conditioner',
#  'Marshall Bluetooth sound system',
#  'Fragonard toiletries',
#  'Eletrolux a\\u00e7o 5 bocas stainless steel gas stove',
#  '\\u201cDermeze\\u201d Moisturising Soap Free Wash body soap',
#  'Free parking garage on premises \\u2013 3 spaces',
#  'electric electric stove',
#  'envirocare shampoo',
#  'Wifi \\u2013 100 Mbps',
#  '49\\" HDTV with standard cable',
#  '44\\" HDTV with Netflix',
#  '65\\" HDTV with premium cabl',
#  'Palmolive conditioner',
#  'Natural Living shampoo',
#  'Dedicated workspace: table and desk',
#  'variada body soap',
#  'Dining area for 6 people',
#  'Suave body soap',
#  'Euro Gas stainless steel oven',
#  'Bosch stainless steel electric stove',
#  'Ren\\u00e9 Furterer shampoo',
#  'Moulinex oven',
#  'Frigidaire oven',
#  'Satellite TV',
#  'Head & Shoulder shampoo',
#  'Fisher Paykel refrigerator',
#  'occitaine conditioner',
#  'Teka induction stove',
#  'Convection Oven stainless steel oven',
#  'Complimentary hot breakfast',
#  'Paid parking garage on premises \\u2013 EUR10 per da',
#  '120\\" HDTV with Amazon Prime Vide',
#  'dial body soap',
#  'Care conditioner',
#  'Samsung or similar refrigerator',
#  'Intermarket  shampoo',
#  'Libherr refrigerator',
#  'Paid parking garage on premises \\u2013 ZAR66 per day',
#  'DE DIETRICH. Four \\u00e0 chaleur tournante. oven',
#  'Bioblas Botanic Oils conditioner',
#  'BOSE SOUNDBAR  Bluetooth sound system',
#  'microdalga  oven',
#  'Smeg - Intergrated fridge /freeze refrigerator',
#  'Brastemp Duplex Frost Free refrigerator',
#  'Self check-in',
#  'Granado conditioner',
#  'Wifi \\u2013 430 Mbps',
#  'Marley Bluetooth sound system',
#  'Sunbeam Mini Oven oven',
#  'Biologico conditioner',
#  "L'Occitane body soap",
#  "L'Or\\u00e9al conditioner",
#  '65\\" HDTV with Netfli',
#  'Table corner guards',
#  'Brastemp inverse refrigerator',
#  'Insedit refrigerator',
#  'Paid washer',
#  'Bio La vie Claire shampoo',
#  'REFRIGERADOR GRANDE COM FREEZER SUPERIOR refrigerator',
#  "Dr Bronner's Castile Soap body soap",
#  'Ice machine',
#  'Irish Spring body soap',
#  'Organics conditioner',
#  'Caixas de som bluetooth embutidas para conex\\u00e3o pelo celular Bluetooth sound system',
#  'First Line refrigerator',
#  'ose sound system with Bluetooth and aux',
#  'Children\\u2019s dinnerware',
#  'Ivory body soap',
#  'petit flacon conditioner',
#  'HDTV with HBO Ma',
#  'mazon Prime Video',
#  'Continental breakfast available \\u2014 \\u20ac8 per person per day',
#  '46\\" HDTV with premium cabl',
#  'teka stainless steel oven',
#  '46\\" HDTV',
#  'Hot water kettle',
#  '12\\" TV',
#  '55\\" HDTV with Netflix',
#  'cooktop stainless steel gas stove',
#  'beko refrigerator',
#  'oku',
#  'Dryer \\u2013\\u00a0In unit',
#  'rascos recicl\\u00e1veis e extratos adquiridos de pequenos agricultores brasileiros. Al\\u00e9m dos extratos da agricultura familia',
#  'Harman Kardon sound system with Bluetooth and aux',
#  'Puracy plant based conditioner',
#  'Bang & Olufsen Bluetooth sound system',
#  'Kayaks',
#  '48\\" HDTV with premium cable',
#  'Breakfast bar',
#  'Natura TodoDia body soap',
#  '45\\" HDTV with Chromecas',
#  'Organics  conditioner',
#  'Public Goods conditioner',
#  'Siemens stainless steel electric stove',
#  '58\\" HDTV with Netfli',
#  'Wifi \\u2013 400 Mbps',
#  'TV with Chromecast',
#  'Generator',
#  'Smeg stove',
#  "Onsite bar \\u2014 S'Bar",
#  'Electric  stainless steel oven',
#  'ar\\u00e7elik stainless steel oven',
#  '43\\" TV with standard cable',
#  'Crib',
#  'Sound system',
#  'Wifi \\u2013 48 Mbps',
#  'eletrico de 2 bocas electric stove',
#  'odelo Yamaha HS5 sound system with aux',
#  'Paid parking garage off premises \\u2013 EUR6 per day',
#  'Walk in closet',
#  'Shared outdoor heated infinity pool',
#  'posso colcoar fog\\u00e3o el\\u00e9trico 2 bocas mediante pedido electric stove',
#  '120\\" HDTV with Apple T',
#  'Occitane shampoo',
#  'Brastemp  refrigerator',
#  'PinoSilvestre body soap',
#  'Paid parking lot on premises \\u2013 ZAR80 per day',
#  '45\\" HDTV',
#  'H&S shampoo',
#  'local PA (see Photo) sound system with aux',
#  'Doss Bluetooth Speaker Bluetooth sound system',
#  'R\\u00e1dio Rel\\u00f3gio Philips \\u2013 Modelo: AJ70300/12 na cor preta Bluetooth sound system',
#  'Alexa Echo Dot sound system',
#  'Small portable type.  oven',
#  'Free residential garage on premises \\u2013 6 spaces',
#  'v\\u00e1riadas body soap',
#  'MIELE refrigerator',
#  'Hamilton Beach oven',
#  'emongrass and Jasmin-Mint Hotel fragrance selected products conditioner',
#  'Garnier body soap',
#  'Top part Fridge/ Bottom Freezer refrigerator',
#  'arzum oven',
#  'Wifi \\u2013 870 Mbps',
#  'Free parking garage on premises \\u2013 2 spaces',
#  'Nuxe/Caudalie toiletries',
#  '14\\" TV with standard cable',
#  'HDTV with premium cabl',
#  'Wolf stainless steel gas stove',
#  'GE stainless steel oven',
#  'Fridge Freezer refrigerator',
#  'Glow Lab conditioner',
#  '50\\" HDTV with Chromecas',
#  '33\\" TV',
#  'Marshall Stockwell 2 sound system with Bluetooth and aux',
#  'Garnier Fructis conditioner',
#  'FRAGONARD toiletries',
#  'Agratto stainless steel electric stove',
#  '30\\" HDTV with Amazon Prime Vide',
#  '47\\" HDTV with Rok',
#  'Portable single plate induction stove',
#  'S\\u0130EMENS refrigerator',
#  'TV with Netflix',
#  'Dedicated workspace: desk and office chair',
#  'hotelin markas\\u0131 conditioner',
#  'seda shampoo',
#  'Acca Kappa body soap',
#  'JVC sound system with Bluetooth and aux',
#  'Evyap body soap',
#  'A\\u00e7elik refrigerator',
#  'Body soap',
#  'Arcelik stainless steel oven',
#  'WHIRPOOL refrigerator',
#  'Hotel conditioner',
#  '42\\" HDTV with Amazon Prime Video',
#  'Smeg gas top elec oven stainless steel gas stove',
#  'Brastemp Retr\\u00f4 refrigerator',
#  'phebo /dove/ body soap',
#  'Valet parking \\u2014 $40/day',
#  'Mrs. Meyers body soap',
#  'Rooftop pool \\u2014 outdoor',
#  'Eletroclux refrigerator',
#  'fridgidare stainless steel gas stove',
#  'Protex shampoo',
#  'TREsemme conditioner',
#  '50\\" HDTV',
#  'Mabe oven',
#  'Complimentary continental breakfast',
#  'Indu\\u00e7\\u00e3o da Eletrolux e um outro eletrico induction stove',
#  'nd wardrobe',
#  'Hunter - made naturally in Melbourn',
#  'Ultimate ears - BOOM 3 Bluetooth sound system',
#  '49\\" HDTV with Apple T',
#  'Cook gas stove',
#  'Alexa  Bluetooth sound system',
#  '02 Bocas electric stove',
#  'Fire pit',
#  'Diversas body soap',
#  'Shared refrigerator & freezer. refrigerator',
#  'Charcoal barbeque',
#  'Onsite rooftop bar \\u2014 cloudM',
#  'ABC body soap',
#  'Elva Domino Hob stainless steel electric stove',
#  'Valet parking \\u2014 $45/day',
#  'Paid parking lot on premises \\u2013 AUD5 per da',
#  '2 burner induction cooktop.  We provide pots and pans. induction stove',
#  '165\\" HDTV with Netfli',
#  'AEG 750 Built-in under counter stainless steel oven',
#  'Game console: PS4 and Xbox One',
#  'onsul stainless steel gas stove',
#  'HDTV',
#  'Consul oven',
#  'bosh oven',
#  '32\\" TV with Apple T',
#  'Savonnettes body soap',
#  'LG stainless steel gas stove',
#  'Onsite restaurant \\u2014 Granada Restaurant',
#  'Children\\u2019s books and toys for ages 5-10 years old',
#  'smeg stainless steel stove',
#  'Pure body soap',
#  'Tommy Bahama shampoo',
#  'cheap one body soap',
#  'Free parking garage on premises \\u2013 25 spaces',
#  'Tedge Bluetooth sound system',
#  'Host greets you',
#  'HDTV with standard cabl',
#  'r. Bronners body soap',
#  'o probado en animales. body soap',
#  '47\\" HDTV with Chromecast',
#  'Smeg Electric stainless steel oven',
#  '47\\" HDTV with Netflix',
#  'Hot water',
#  'Clicks conditioner',
#  'Com freezer refrigerator',
#  'Acca Kappa shampoo',
#  'Bosch oven and gas hob stainless steel oven',
#  'rainbow  Bluetooth sound system',
#  '24\\" HDTV with Chromecas',
#  'Free parking on premises \\u2013 3 spaces',
#  'sony sound system with Bluetooth and aux',
#  'Hisense  stainless steel gas stove',
#  'LA VIE EN VERT shampoo',
#  'Onsite bar \\u2014 E7 Bar',
#  '58\\" HDTV with Chromecas',
#  'ves Roche',
#  'Tresemm\\u00e9 conditioner',
#  'Candy induction stove',
#  'Vestel  refrigerator',
#  'TREsemme shampoo',
#  'Org\\u00e1nico shampoo',
#  'solo su richiesta shampoo',
#  'Dove Deep Moisture body soap',
#  'L\\u00e9a Nature Karit\\u00e9 shampoo',
#  'Mabe stainless steel oven',
#  'Onsite rooftop bar \\u2014 Mykonos Bleu Restaurant & Rooftop',
#  'Wifi \\u2013 55 Mbps',
#  'Harmon Cardon Bluetooth Speakers Bluetooth sound system',
#  'UE Wonderboom Bluetooth sound system',
#  'Garnier-Thiebaut linens',
#  'Electrolux  stainless steel oven',
#  '100\\" HDTV with Amazon Prime Vide',
#  'Walk-in pantry',
#  'hear and shoulder shampoo',
#  'Bosh stainless steel oven',
#  'LaBottega shampoo',
#  'Wifi \\u2013 1024 Mbps',
#  'Free driveway parking on premises \\u2013 1 space',
#  'LG smart Tech refrigerator',
#  '74\\" HDTV with Chromecast',
#  'Self-parking \\u2014 $50/stay',
#  'MUHTEL\\u0130F MARKA conditioner',
#  'Wifi \\u2013 5300 Mbps',
#  'ELETROLUX stainless steel gas stove',
#  'BOSCH induction stove',
#  'Liebherr refrigerator',
#  'Sonos via wifi sound system',
#  'Cooktop  5 bocas Brastemp gas stove',
#  '39\\" TV with Netflix',
#  'Clothing storage: wardrobe and closet',
#  'Eletrolux gas stove',
#  'Daewoo con congelador y agua purificada refrigerator',
#  'Eletrolux DF52X refrigerator',
#  'Induction plate induction stove',
#  'TV Samsung sound system with Bluetooth and aux',
#  'Vestel stainless steel oven',
#  'luxury body soap',
#  'Muxima Guest House shampoo',
#  'Apple & Bose  Bluetooth sound system',
#  'Sukin  body soap',
#  'siemens stainless steel oven',
#  'shampoo e condicionador conditioner',
#  'Smeg refrigerator',
#  '37\\" TV with Amazon Prime Video',
#  'Micro wave and ceramic cook top electric stove',
#  'TV with Roku',
#  'Paid parking lot on premises \\u2013 BRL60 per da',
#  'marantz Am',
#  'Paid parking lot on premises \\u2013 EUR25 per da',
#  'Neutro body soap',
#  'Stainless steel electric stove',
#  'Wifi \\u2013 20 Mbps',
#  'Hospitality products from Linon body soap',
#  'Salvatore Ferragamo body soap',
#  'Coslys body soap',
#  'Profilo b\\u00fcy\\u00fck boy dolap refrigerator',
#  'Paid parking garage on premises \\u2013 EUR8 per da',
#  'Small electric 2 plate hob and oven electric stove',
#  'Omnisens body soap',
#  'Wifi \\u2013 120 Mbps',
#  'No SLS or Parabens. Essential oils from pharmacy. body soap',
#  'convection/microwave oven',
#  '28\\" HDTV with Netflix',
#  'odelo de hotel. body soap',
#  "Onsite restaurant \\u2014 Gleason's Tavern",
#  'DOVE Nutritive Secrets Acondicionador conditioner',
#  'LA VIE EN VERT conditioner',
#  'Black and Decker stainless steel oven',
#  'Wifi \\u2013 3167 Mbps',
#  'Yamaha Bluetooth sound system',
#  'Sonos sound system with Bluetooth and aux',
#  '55\\" HDTV with premium cable',
#  '58\\" HDTV with Netflix',
#  'Onsite restaurant \\u2014 Bel Ami Caf\\u00e9',
#  'stove top gas stove',
#  'Neutro Balance body soap',
#  'Pond',
#  '\\u00c1rgan oil of Morocco shampoo',
#  'SAMSUNG refrigerator',
#  'Shared saltwater pool',
#  '107\\" HDTV',
#  'naturals  shampoo',
#  'Denon Bluetooth sound system',
#  'dove  body soap',
#  'Sukrin shampoo',
#  '46\\" TV with standard cable',
#  '2 r\\u00e9frig\\u00e9rateur encastr\\u00e9s refrigerator',
#  'Fog\\u00e3o 4 bocas Itatiaia com forno e acendimento manual oven',
#  'Paid parking garage off premises \\u2013 $50 per day',
#  'Samsung Side by Side refrigerator',
#  'DIAL body soap',
#  'T.TAIO Esponjab\\u00f3n body soap',
#  'DVD player',
#  'Stainless Steel Fridgedare refrigerator',
#  'Tresemme conditioner',
#  'regal refrigerator',
#  'Duru body soap',
#  'Lux ou similar body soap',
#  'En \\u00e1reas comunes refrigerator',
#  'Head Shoulders shampoo',
#  'La Dimora body soap',
#  'Paid parking garage off premises',
#  'WHIRPOOL stainless steel oven',
#  '50\\" HDTV with standard cable',
#  'Fraga gas stove',
#  'Wifi \\u2013 1000 Mbps',
#  'Very hot oven',
#  'BO Ma',
#  '41\\" HDTV with Netflix',
#  'Hitachi refrigerator',
#  'Lacanche oven',
#  'Continental stainless steel gas stove',
#  'defy refrigerator',
#  'Cooking basics',
#  'luetoot',
#  'Dennon / Canton sound system with aux',
#  'DEFY refrigerator',
#  'Smeg with ice and water dispenser refrigerator',
#  'Defy electric stove',
#  'Cooktop gas stove',
#  'sony sound system with aux',
#  'NEFF stainless steel oven',
#  'Consul du',
#  'Electrolux  stainless steel gas stove',
#  'Game console: Nintendo Switch and PS4',
#  'Juliet balcony',
#  'Fitness center',
#  'Beko gas stove',
#  'Evyap conditioner',
#  'Clothing storage: walk-in closet and wardrobe',
#  'Sony sound system with aux',
#  'Amazon Alexa Bluetooth sound system',
#  'Miss lyn body soap',
#  'Teca stainless steel gas stove',
#  'eletrolux stainless steel gas stove',
#  'AEG touch stainless steel electric stove',
#  'Wine cellar',
#  'Wood-burning fireplace',
#  'Eletrolux Duas Portas refrigerator',
#  'Harmon Kardon Bluetooth sound system',
#  'cookto',
#  'samsung Bluetooth sound system',
#  'Courtyard',
#  'Frigidaire stainless steel oven',
#  'iPad Air sound system',
#  '81\\" TV with Roku',
#  'AFRICOLOGY shampoo',
#  'bertazonni stainless steel oven',
#  'Def',
#  'High chair',
#  'Onsite restaurant \\u2014 Sapori Dal Mondo Restaurant',
#  'Neutr',
#  '65\\" HDTV with Apple T',
#  'Aveda conditioner',
#  'ois tem formula\\u00e7\\u00e3o biodegrad\\u00e1ve',
#  'pantene conditioner',
#  'Malin+Goetz toiletries',
#  'Wifi \\u2013 16 Mbps',
#  '50\\" HDTV with Rok',
#  'French Door Full Sized Fridge refrigerator',
#  'Candy stainless steel oven',
#  'Dedicated workspace: monitor',
#  'Electric blinds',
#  'Ines de la Fressange conditioner',
#  'various brands - liquid form body soap',
#  '28\\" TV with Netflix',
#  '55\\" HDTV with Rok',
#  'Defy (Electric) stainless steel oven',
#  '143\\" HDTV with Chromecas',
#  'nd monitor',
#  'Continental breakfast available \\u2014 \\u20ac16 per person per day',
#  '60\\" HDTV with Netflix',
#  'Samsung sound system with Bluetooth and aux',
#  '65\\" TV with premium cable',
#  'Ortigia conditioner',
#  'R\\u00e1dio AM/FM Entrada USB sound system with aux',
#  'Mixed brands body soap',
#  'neutro  shampoo',
#  'Breakfast',
#  'el\\u00e9trico novo stainless steel oven',
#  'Stainless steel induction stove',
#  'Paid parking garage off premises \\u2013 EUR3 per day',
#  'ody wash and conditioner silicone free  conditioner',
#  'Samsung sound system with aux',
#  'o fog\\u00e3o stainless steel oven',
#  'Teka stainless steel gas stove',
#  'lidor or pantene conditioner',
#  'TRESemm\\u00e9 shampoo',
#  'Shared outdoor infinity rooftop pool',
#  'Free parking on premises \\u2013 2 spaces',
#  'organic body soap',
#  'Pineda Covalin conditioner',
#  'Cooktop Tramontina 04 bocas stainless steel gas stove',
#  'Ariston stainless steel gas stove',
#  'Savon liquide Petit Marseillais body soap',
#  'Denon Amplifier sound system with Bluetooth and aux',
#  'Officine del Mugello (vegan ok) body soap',
#  'Sony & Technic sound system with aux',
#  'Alexa  sound system with Bluetooth and aux',
#  'Molton Brown  body soap',
#  '43\\" HDTV with Netfli',
#  '23\\" TV with Netflix',
#  'Decorative fireplace',
#  "L'Erbolario ginepro nero shampoo",
#  '40\\" TV with premium cable',
#  'per mani/viso/doccia body soap',
#  'LG stainless steel oven',
#  'Loredana conditioner',
#  'Paid street parking off premises \\u2013 EUR4 per hour',
#  'Savon bio body soap',
#  'Paid parking lot on premises \\u2013 AUD10 per da',
#  'Game console: Xbox 360',
#  'Dryer \\u2013 In building',
#  'Concierge',
#  'Lavarino body soap',
#  'Creative sound system with Bluetooth and aux',
#  'HDTV with Netflix',
#  'Air-Fryer oven',
#  'Consul 280L refrigerator',
#  'Fisher Paykel stainless steel induction stove',
#  'Rio Spot Homes conditioner',
#  'Hotel body soap',
#  'Glow Lab body soap',
#  'Terrace',
#  '49\\" TV with Netflix',
#  'lihljkhkljhklj shampoo',
#  'SAMSUNG Double Door with Ice Maker refrigerator',
#  'Loreal shampoo',
#  'MONSAVON body soap',
#  'Paid street parking off premises \\u2013 AUD8 per hour',
#  'Free driveway parking on premises \\u2013 8 spaces',
#  'Sam Sung refrigerator',
#  'Paid parking garage on premises \\u2013 ZAR75 per da',
#  'Midea Induction single hotplate induction stove',
#  'Aderma body soap',
#  'Eletrolux refrigerator',
#  'Free parking garage on premises \\u2013 1 space',
#  'Google Home Bluetooth sound system',
#  'Smeg oven',
#  'Bosch induction cooktop induction stove',
#  'ara cada h\\u00f3spede para que tenham uma op\\u00e7\\u00e3o na chegada caso n\\u00e3o estejam trazendo o seu sabonete pessoal.  body soap',
#  'Dispenser for shampoo & bodywash in shower shampoo',
#  'Paid parking garage on premises',
#  'Ironing board',
#  'liquido  body soap',
#  'Yves Rocher conditioner',
#  '43\\" HDTV',
#  'Electrolux electric stove',
#  'Dance floor',
#  'Larisse shampoo',
#  'Barazza stainless steel oven',
#  'Paid washer\\u2013In building',
#  'nd office chair',
#  'Healing Earth conditioner',
#  'Mountain view',
#  'Supermarket brand shampoo shampoo',
#  '80\\" HDTV with Netflix',
#  'Lampada Speaker Bluetooth sound system',
#  'Rice maker',
#  'cooktop 2 bocas electric stove',
#  'Cabasse sound system with aux',
#  '30\\" HDTV',
#  'VESTEL stainless steel oven',
#  'Tennis court',
#  'Brastemp stainless steel electric stove',
#  'Valet parking \\u2014 $200/day',
#  'Toshiba  refrigerator',
#  'Shower bathtub combo',
#  'Onsite rooftop bar \\u2014 cloudM Rooftop bar',
#  'Audiopro sound system with Bluetooth and aux',
#  'Leibherr refrigerator',
#  'Biodegradabl',
#  'westinghouse  refrigerator',
#  'La cocina est\\u00e1 dise\\u00f1ada para hacer platillos sencillo',
#  'Bio-degradable Aloe Vera & Cucumber  body soap',
#  'Dia',
#  'lose',
#  'Paid valet parking on premises',
#  'ous vous fournissons. shampoo',
#  'Paid parking garage off premises \\u2013 EUR39 per day',
#  'Spa access',
#  'LG CM3430W CD Micro Audio Player with built-in WiFi & Subwoofe',
#  'Phebo liquido body soap',
#  'Wifi \\u2013 25 Mbps',
#  '35\\" HDTV with premium cable',
#  'Xampu shampoo',
#  'Shampoo',
#  'bosch induction stove',
#  'Spa equipment',
#  'Omnisens Paris conditioner',
#  'Healing earth conditioner',
#  'Onsite bar',
#  'Vegan high end brand conditioner',
#  'Shampoo Mini de cortesia shampoo',
#  'Haier 222l refrigerator',
#  'Heated floors',
#  'Saba refrigerator',
#  '2 bocas portatil electric stove',
#  'Phone',
#  'bio body soap',
#  'Polaroid sound system with Bluetooth and aux',
#  'Beach essentials',
#  'SMEG gas oven  stainless steel oven',
#  'Induction cooker induction stove',
#  'Freezer',
#  'Arbonne shampoo',
#  'Siemens stainless steel oven',
#  'LOFRA stainless steel oven',
#  'Brastemp Duplex refrigerator',
#  'Bar Fridge only refrigerator',
#  'Rooftop pool with poolside bar \\u2014 outdoo',
#  'Fisher and Paykel refrigerator',
#  '70\\" HDTV with Netfli',
#  'cassa acustica APPLE e GOOGLE assistant  sound system with Bluetooth and aux',
#  'tramontina gas stove',
#  'Paid parking lot on premises \\u2013 40 spaces',
#  'Port\\u00e1til  electric stove',
#  'e hotelari',
#  'Due ripiani  refrigerator',
#  'the best body soap',
#  'Paid parking garage on premises \\u2013 1000 spaces',
#  'Continental breakfast available \\u2014 \\u0e3f270 per person per day',
#  'HiSense refrigerator',
#  'organic paraben free  body soap',
#  'national shampoo',
#  'AESOP body soap',
#  'Mellerware induction stove',
#  'Neff x 2 ovens (one is steam) oven',
#  'Paid parking lot off premises \\u2013 $4 per day',
#  'Tresemme shampoo',
#  'Onsite rooftop bar \\u2014 Last Light',
#  'Fountain',
#  'guest soap body soap',
#  'HDTV with Roku',
#  'Organic Care conditioner',
#  'Pantein body soap',
#  'Haier 220l refrigerator',
#  'Bathroom essentials',
#  'brasntemp refrigerator',
#  'Clean body soap',
#  "Onsite bar \\u2014 Gleason's Tavern",
#  'Boots conditioner',
#  'Wifi \\u2013 35 Mbps',
#  'Shared outdoor heated pool',
#  '27\\" HDTV with Chromecas',
#  'Kayak',
#  'Older model stove - a lighter is required to ignite the gas. Lighter will be provided in the kitchen bench. gas stove',
#  'Brand may vary - high quality conditioner',
#  'Free parking garage on premises \\u2013 5 spaces',
#  '55\\" HDTV with Netfli',
#  'Room service',
#  'general elektrik refrigerator',
#  'Clothing storage: walk-in closet',
#  ' space',
#  'Plaque de cuisson oven',
#  'Wet bar',
#  'SIEMENS stainless steel oven',
#  'Loccitaine conditioner',
#  'Gilchrist & Soames toiletries',
#  '92\\" HDTV',
#  'Folicure shampoo',
#  'Onsite restaurant \\u2014 La Cuisine de l\\u2019E7',
#  'Just Lynne  body soap',
#  'Vulcan oven',
#  'Shared gym in building',
#  'Beach chairs',
#  'Pool toys',
#  '50\\" TV with Netfli',
#  'WOOLWORTHS shampoo',
#  '40\\" HDTV with Amazon Prime Vide',
#  '52\\" HDTV with Apple T',
#  'Gas stove',
#  'BOSE SOUNDTOUCH 20 Bluetooth sound system',
#  'Forno do fog\\u00e3o oven',
#  'generico body soap',
#  'Wifi \\u2013 45 Mbps',
#  '82\\" HDTV',
#  'Shared outdoor olympic-sized pool',
#  '39\\" HDTV with standard cable',
#  'Hi-FI CD and radio sound system',
#  'Leif body soap',
#  'Smeg electric stove',
#  'GBC Bluetooth sound system',
#  'Geral gas stove',
#  'N\\u00e3o h\\u00e1 reposi\\u00e7\\u00e3o body soap',
#  'Miele induction stove',
#  'basico stainless steel oven',
#  'almolive body soap',
#  'Wifi \\u2013 21 Mbps',
#  'Frette linens',
#  'Garden',
#  'Game console: PS5 and Xbox 360',
#  'Indoor fireplace',
#  'Bio body soap',
#  'Free driveway parking on premises \\u2013 2 spaces',
#  'Bosch  stainless steel oven',
#  'Pansonic refrigerator',
#  'neutro hipoalergenico body soap',
#  'Arbonne conditioner',
#  'Washer',
#  'Paid parking lot on premises \\u2013 3 spaces',
#  'ORGANICO conditioner',
#  'Venax oven',
#  '22\\" HDTV',
#  '24-hour fitness center',
#  'Natura conditioner',
#  'Guesthouse  shampoo',
#  'Natura TodoDia shampoo',
#  'Shared hot tub',
#  '42\\" HDTV with Apple T',
#  'HDTV with Netfli',
#  'varies  conditioner',
#  'logitech Bluetooth sound system',
#  'Grill seulement oven',
#  'sharp stainless steel stove',
#  'Onsite rooftop bar \\u2014 Rooftop Sky Stars Bar',
#  "L'Occitane de Provence  body soap",
#  'Smeg stainless steel gas stove',
#  'GE oven',
#  '30\\" HDTV with Netflix',
#  '2 caixas sony Bluetooth sound system',
#  'Wifi \\u2013 140 Mbps',
#  'Paid street parking off premises \\u2013 EUR6 per day',
#  'Paid parking garage off premises \\u2013 EUR10 per day',
#  'Shared fenced garden or backyard',
#  'Brastemp oven',
#  'Single burner countertop range electric stove',
#  "ohnson's body soap",
#  'Monodose  conditioner',
#  'Paid parking garage off premises \\u2013 $65 per day',
#  'francis body soap',
#  'OMEGA stainless steel gas stove',
#  'Free parking garage on premises \\u2013 100 spaces',
#  'Consu',
#  'Dr. Bronner All in one body soap',
#  'rebul conditioner',
#  'Tresemm\\u00e9 shampoo',
#  ' bocas stainless steel gas stove',
#  'HDTV with Apple TV',
#  'Le Labo toiletries',
#  'Molton Brown body soap',
#  'Ariston stainless steel oven',
#  'Paid parking garage off premises \\u2013 $45 per day',
#  'creative sound system with Bluetooth and aux',
#  'Wifi \\u2013 135 Mbps',
#  '70\\" HDTV with standard cable',
#  'Authentic Properties body soap',
#  'TOSHIBA refrigerator',
#  'smeg stainless steel electric stove',
#  'Liquid body soap',
#  '42\\" HDTV with premium cable',
#  'Hisence refrigerator',
#  'nd walk-in closet',
#  'Smegg electric oven oven',
#  'dove conditioner',
#  '82\\" HDTV with Netfli',
#  'Echo Dot Bluetooth sound system',
#  'badedas/nivea shampoo',
#  'Toiletries',
#  'Bosch - Electric oven oven',
#  'Roku Bluetooth sound system',
#  'Security monitors',
#  'continental refrigerator',
#  'Wine storage',
#  'Paid parking garage on premises \\u2013 $10 per da',
#  'nd desk',
#  'Free parking on premises \\u2013 6 spaces',
#  'Pocket wifi',
#  'Self-parking \\u2014 $50/day',
#  'sabonete l\\u00edquido PROTEX body soap',
#  'Paid street parking off premises \\u2013 EUR35 per stay',
#  'Generic Vegan conditioner',
#  'Dining area for 10 people',
#  'REBUL shampoo',
#  'Netflix',
#  'Cooked-to-order breakfast available \\u2014 $15 per person per day',
#  'Desk',
#  'Sonos sound system',
#  'Paid parking lot on premises \\u2013 MXN200 per day',
#  'Clothing storage: closet and dresser',
#  'Two shelves in fridge for use refrigerator',
#  'Organic  body soap',
#  'AFRICOLOGY body soap',
#  'buklet body soap',
#  'Fisher & Paykel stainless steel gas stove',
#  'Walita oven',
#  'multiple hotel-size trials of high-end brands conditioner',
#  'Free driveway parking on premises \\u2013 5 spaces',
#  '49\\" HDTV with Netfli',
#  ' french brand made 100% with Marseille Soap  body soap',
#  'Free dryer',
#  'Generic Vegan shampoo',
#  'Prince body soap',
#  'Game room',
#  'OX shampoo',
#  'Airplay / Chromecast speaker sound system',
#  'Pantene body soap',
#  'BOSCH stainless steel gas stove',
#  'Game console: Nintendo Wii',
#  'Bosch stove',
#  'Samsung double-doo',
#  'Hot tub',
#  '38\\" TV with Netflix',
#  'Tres Somme conditioner',
#  'Steam room',
#  'Outlet covers',
#  'Free residential garage on premises \\u2013 1 space',
#  '24\\" HDTV',
#  'Onsite bar \\u2014 Crown Shy',
#  'Viking stainless steel gas stove',
#  'Heated pool',
#  'SMEG stainless steel oven',
#  'Paid parking garage off premises \\u2013 EUR5 per day',
#  'Paid parking garage on premises \\u2013 $15 per da',
#  'different brands at different times body soap',
#  'Dayton Audio Bluetooth sound system',
#  'Wifi \\u2013 15 Mbps',
#  'iss Lynn. body soap',
#  'buklet shampoo',
#  'Private indoor lap pool',
#  'Pour-over coffee',
#  'Nioxin  shampoo',
#  'petite marseille or palmolive body soap',
#  'mazon Prime Vide',
#  'teka stainless steel electric stove',
#  'Clothing storage: wardrobe and walk-in closet',
#  'Codage toiletries',
#  'Onsite restaurant \\u2014 Mykonos Bleu Restaurant & Rooftop',
#  'Limited housekeeping \\u2014 weekly',
#  '52\\" HDTV',
#  'Gautier Bluetooth sound system',
#  'House bikes',
#  'Paid parking lot off premises \\u2013 BRL3 per hour',
#  'LOREAL shampoo',
#  '29\\" TV with standard cable',
#  ' linha respeita a natureza e promove o turismo sustent\\u00e1ve',
#  'Aspar conditioner',
#  'Homepod (Apple) sound system',
#  '24\\" TV with standard cable',
#  'Glass top hob electric stove',
#  'Electrolux induction stove',
#  'smeg electric stove',
#  'Rituals body soap',
#  'Lux and Organics body soap',
#  'lactovit body soap',
#  'Chef oven',
#  'Bar Fridge. Under counter. refrigerator',
#  'Telescope',
#  'Sauter stainless steel oven',
#  '43\\" HDTV with Amazon Prime Video',
#  'samsung refrigerator',
#  'Cadum ou Fer \\u00e0 Cheval body soap',
#  'White Westinhouse refrigerator',
#  'Free driveway parking on premises \\u2013 4 spaces',
#  'R\\u00e9frigerateur cong\\u00e9lateur marque Siemens refrigerator',
#  'Free residential garage on premises \\u2013 4 spaces',
#  'Infinity pool',
#  'Valet parking \\u2014 $90/day',
#  'Laundromat nearby',
#  'Portable Induction 1 pot stove induction stove',
#  'Onsite restaurant \\u2014 Crown Shy',
#  'electrolux stainless steel oven',
#  'inist\\u00e9rio do Desenvolvimento Agr\\u00e1rio e SEBRAE.  shampoo',
#  '50\\" TV',
#  'neutro body soap',
#  '41\\" HDTV with premium cable',
#  'Onsite bar \\u2014 Clinton Hall & Rooftop Beer Garden',
#  'var\\u00eda body soap',
#  'Siemen',
#  'Large Toaster Oven. oven',
#  'Stove',
#  'Wifi \\u2013 50 Mbps',
#  'Restaurant',
#  'Le Cinq Codet toiletries',
#  'ffice chai',
#  'Wifi \\u2013 240 Mbps',
#  'Marshall sound system with Bluetooth and aux',
#  'Carbon monoxide alarm',
#  'Paid valet parking on premises \\u2013 4 spaces',
#  'Puracy or Jr Watkins conditioner',
#  '48\\" HDTV with Apple T',
#  'Free parking garage on premises \\u2013 807 spaces',
#  'Fridge and freezer combo refrigerator',
#  '24\\" HDTV with premium cable',
#  'Wifi \\u2013 220 Mbps',
#  'Paid parking garage off premises \\u2013 BRL15 per hour',
#  'Propia body soap',
#  'Koblenz stainless steel induction stove',
#  'Argan oil of Morocco conditioner',
#  'Natural soap body soap',
#  'Miele refrigerator',
#  'Savon de marseille body soap',
#  'Harman Kardon sound system with aux',
#  'Continental breakfast available \\u2014 R$32 per person per day',
#  '100\\" HDTV with Netflix',
#  'Wifi \\u2013 56 Mbps',
#  '206\\" HDTV with Netflix',
#  'BRASTEMP refrigerator',
#  'Undercounter fridge refrigerator',
#  'Sono',
#  'Marantz Bluetooth sound system',
#  'Indel Marine Isotherm refrigerator',
#  '165\\" HDTV',
#  'large Samsung frige will a sperate frezer  refrigerator',
#  'forno el\\u00e9trico pequeno na cozinha compartilhada oven',
#  'Palmolive body soap',
#  'Electrolux. Duplex. refrigerator',
#  'Regina Spa Therapy  shampoo',
#  '32\\" TV with Chromecast',
#  'Paid parking lot off premises \\u2013 $8 per day',
#  'Paid street parking off premises \\u2013 EUR2 per day',
#  'Marshall Speaker Bluetooth sound system',
#  'RITUALS body soap',
#  '40\\" TV with Netflix',
#  'Onsite restaurant \\u2014 Cancino',
#  '50\\" TV with Netflix',
#  'Alarm system',
#  'Bvlgari shampoo',
#  'bosch refrigerator',
#  'jhonson body soap',
#  'Moroccan Oil conditioner',
#  'Vestel stainless steel gas stove',
#  'cheap shampoo',
#  'Uriage body soap',
#  'mabe refrigerator',
#  'Valet parking \\u2014 \\u20ac40/day',
#  'pantene  conditioner',
#  'Free parking on premises \\u2013 4 spaces',
#  'Anker Bluetooth sound system',
#  'LG Bluetooth sound system',
#  'CLASSIQUE shampoo',
#  'Miss Lyn body soap',
#  'Electric oven oven',
#  'Free carport on premises \\u2013 2 spaces',
#  'Brastemp  gas stove',
#  'Sonos sound system with aux',
#  'defy small fridge refrigerator',
#  'Ines de La Fressange  body soap',
#  'Subzero refrigerator',
#  'Ceiling fans',
#  'Smoke alarm',
#  'Golez conditioner',
#  'Healing Earth (Sulphate Free) shampoo',
#  'ROSIERES electric stove',
#  '2 stove tops mini - not a full stove/oven. Suitable for small meals electric stove',
#  'Bosch - Induction hob induction stove',
#  'plaque de cuisson 5 feux marque Neff gas stove',
#  'Elseve shampoo',
#  'Ritual body soap',
#  "Trader Joe's shampoo",
#  '32\\" HDTV with Rok',
#  'Sauna',
#  'sony Bluetooth sound system',
#  'PRO LINE refrigerator',
#  'KMS Salon grade shampoo',
#  'Phillips sound system with Bluetooth and aux',
#  '81\\" TV with standard cable',
#  'GE Profile stainless steel gas stove',
#  'our product shampoo',
#  'ILVE stainless steel gas stove',
#  'Fireplace guards',
#  'Dining area for 8 people',
#  'Free carport on premises \\u2013 25 spaces',
#  'Bluetooth / TV Bluetooth sound system',
#  'BOSE sound system with Bluetooth and aux',
#  'Duplex - frost free refrigerator',
#  'Hamilton beach induction stove',
#  'Petit Marseillais body soap',
#  'Tiny Bar Fridge refrigerator',
#  'Anko oven',
#  '42\\" HDTV with standard cable',
#  'Vestel refrigerator',
#  'neutral body soap',
#  'large toaster oven oven',
#  'pantene shampoo',
#  '32\\" TV with Netfli',
#  'MABE oven',
#  'It varies conditioner',
#  'Private outdoor heated saltwater pool',
#  '40\\" HDTV with standard cable',
#  'house brand conditioner',
#  'n\\u00edvea  body soap',
#  'AD sound system with Bluetooth and aux',
#  'cooktop gas stove',
#  'Bang&Olufsen sound system',
#  'L\\u00f3ccitane body soap',
#  "L' Occitane body soap",
#  'Wifi \\u2013 10030 Mbps',
#  'Paid parking garage on premises \\u2013 BRL10 per da',
#  'Paid street parking off premises \\u2013 EUR2 per hour',
#  'duplex refrigerator',
#  'Gorenge refrigerator',
#  'Bosch stainless steel gas stove',
#  'X sound system with aux',
#  'Defy stainless steel gas stove',
#  'Aspar Botanical Hair Shampoo shampoo',
#  'franke refrigerator',
#  'Gg gas stove',
#  'N\\u00edvea ou Granado body soap',
#  'Woolworths  body soap',
#  'neutral shampoo',
#  "Parrilla de 20''. Cuenta con 2 quemadores y una cubierta porcelanizada que facilita la limpieza. gas stove",
#  'Natural skincare products shampoo',
#  'Aro body soap',
#  'Super Flama gas stove',
#  'AFRICOLOGY conditioner',
#  'Pentene body soap',
#  'Philco stainless steel oven',
#  'Roberto Naldi Collection toiletries',
#  ...}

# %%
unique_values1= pd.DataFrame(list(unique_values))

# %%
unique_values1.to_excel('unique_values.xlsx')

# %% [markdown]
# # Count how many times each unique value

# %%
#créer table avec les valeurs uniques et le compte de ces valeurs 
count=amenities.apply(pd.value_counts)

# %%
#insérer la colonne sum_count et additioner les valeurs 
count.insert(loc=0, column='sum_count', value=count.sum(axis=1))

# %%
#trier les valeurs du plus grand au plus petit
count.sort_values("sum_count", axis = 0, ascending = False,
                 inplace = True, na_position ='last')

# %%
#display the most recurent
count2=count["sum_count"]
count2.head(10)
# Out:
# Wifi                       260090.0
# Essentials                 253532.0
# Long term stays allowed    241054.0
# Kitchen                    240923.0
# TV                         213037.0
# Hangers                    211356.0
# Hair dryer                 188724.0
# Iron                       187756.0
# Washer                     185073.0
# Heating                    184327.0
# Name: sum_count, dtype: float64

# %% [markdown]
# # Add Primary Key

# %%
#add Listing_id
amenities.insert(loc=0, column='Listing_id', value=all_data["listing_id"])
amenities.head(1)
# Out:
#    Listing_id        0        1       2     3                        4     5  \
# 0      281420  Heating  Kitchen  Washer  Wifi  Long term stays allowed  None
#
#       6     7     8  ...    79    80    81    82    83    84    85    86  \
# 0  None  None  None  ...  None  None  None  None  None  None  None  None
#
#      87    88
# 0  None  None
#
# [1 rows x 90 columns]

# %%
#create excel doc
amenities.to_excel('Amenities.xlsx')
