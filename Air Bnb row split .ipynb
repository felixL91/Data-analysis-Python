# %% [markdown]
# # Import libraries and data

# %%
import os
import pandas as pd
import numpy as np

all_data = pd.read_csv("Listings.csv")
# Out:
# /Users/felixleonard/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (5,13) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %% [markdown]
# # Get the column amenities and delet the last character

# %%
all_data2=all_data["amenities"].str[:-1]
all_data2.head(1)
# Out:
# 0    ["Heating", "Kitchen", "Washer", "Wifi", "Long...
# Name: amenities, dtype: object

# %%
amenities= all_data2.str.split(',', expand=True)
amenities.head(1)
# Out:
#            0           1          2        3                           4   \
# 0  ["Heating"   "Kitchen"   "Washer"   "Wifi"   "Long term stays allowed"
#
#      5     6     7     8     9   ...    79    80    81    82    83    84  \
# 0  None  None  None  None  None  ...  None  None  None  None  None  None
#
#      85    86    87    88
# 0  None  None  None  None
#
# [1 rows x 89 columns]

# %%
 for i in range(89):
        amenities[i]= amenities[i].str[2:-1]
amenities.head(1)

# %% [markdown]
# # Get unique values in all columns and Create excel file unique values

# %%
unique_values = set()
for col in amenities:
    unique_values.update(amenities[col])
unique_values
# Out:
# {'',
#  'Personal  conditioner',
#  'Brands vary. conditioner',
#  'Sound system with aux',
#  'Rice maker',
#  '52\\" TV',
#  'Paid parking lot off premises \\u2013 BRL3 per hour',
#  'Tipo amenities hotel body soap',
#  'Brastemp electric stove',
#  'Free residential garage on premises \\u2013 2 spaces',
#  'Small under counter refrigerator',
#  'No SLS or Parabens. Essential oils from pharmacy. body soap',
#  'electric cook top stove',
#  '49\\" HDTV',
#  'Milton Brown conditioner',
#  'high end shampoo and conditioner shampoo',
#  'Convection Oven stainless steel oven',
#  'Stand alone rain shower',
#  '43\\" HDTV with Netflix',
#  'Garage parking',
#  'Spa equipment',
#  'organics shampoo',
#  'MUHTEL\\u0130F MARKA conditioner',
#  'REBUL body soap',
#  'le petit marseillais body soap',
#  'Dedicated workspace: table',
#  '62\\" HDTV with Amazon Prime Vide',
#  '92\\" HDTV',
#  'Pour-over coffee',
#  'Dove ou similar body soap',
#  'Dennon / Canton sound system with aux',
#  'variadas body soap',
#  'Smeg gas top elec oven stainless steel gas stove',
#  'jbl sound system with Bluetooth and aux',
#  'Lagan  refrigerator',
#  'Eletrolux induction stove',
#  'Bar Fridge. Under counter. refrigerator',
#  '32\\" HDTV with premium cabl',
#  'keep care body soap',
#  '3m conditioner',
#  'Modjadji conditioner',
#  'Self-parking \\u2014 \\u20ac20/stay',
#  'VENAX gas stove',
#  'Earth Essentials conditioner',
#  'AEG touch stainless steel electric stove',
#  'Sauna',
#  'Paid parking garage off premises \\u2013 $30 per day',
#  'Hammam',
#  'CAMAY PALMOLIVE body soap',
#  'Juliet balcony',
#  'Geneva Guild toiletries',
#  'neffe stainless steel gas stove',
#  'Mini Bluetooth sound box Bluetooth sound system',
#  'Rituals body soap',
#  'Paid parking garage off premises \\u2013 MXN15 per day',
#  'PRIJA body soap',
#  'Various shampoo',
#  'Bioblas Botanic Oils shampoo',
#  'Paid parking garage on premises \\u2013 EUR5 per day',
#  'Free residential garage on premises \\u2013 4 spaces',
#  'Marantz sound system',
#  'blenda',
#  'Shikai - natural plant based shampoo',
#  'DS & Durga conditioner',
#  'Siemens stainless steel gas stove',
#  'NEUTRO body soap',
#  'logitech Bluetooth sound system',
#  'Washer \\u2013\\u00a0In unit',
#  'Phillips sound system with Bluetooth and aux',
#  'basico refrigerator',
#  "L'Or\\u00e9al conditioner",
#  'Sony sound system',
#  'MIELE stove',
#  'URIAGE GEL DERMATOLOGIQUE body soap',
#  'Onsite restaurant \\u2014 Molyvos Greek Restaurant',
#  'un kit completo solo para la primera noche shampoo',
#  'Natura body soap',
#  'BOSCH KDN 49 refrigerator',
#  'Thomson sound system with Bluetooth and aux',
#  '48\\" HDTV with Netflix',
#  'Clicks pharmacy brand body soap',
#  'Pool cover',
#  'ELETRICO BRITANIA oven',
#  'HDTV with Amazon Prime Video',
#  'Library',
#  'Miele stainless steel oven',
#  '105\\" HDTV with Apple T',
#  'SMEG & Siemens stainless steel oven',
#  'nd desk',
#  'samsung sound bar Bluetooth sound system',
#  'Room-darkening shades',
#  'Fridgedare Stainless Steel refrigerator',
#  'Tramontina stainless steel induction stove',
#  'Clothing storage: closet and wardrobe',
#  'ge refrigerator',
#  '7 Plantes Cien shampoo',
#  'u00e9 um fogareiro el\\u00e9trico de 1 boca. electric stove',
#  'Le Cinq Codet toiletries',
#  'Eletrolux Duas Portas refrigerator',
#  'Marshall Stanmore sound system with Bluetooth and aux',
#  'It varies shampoo',
#  'Iwori - Beauty without Cruelty shampoo',
#  'Aesop  body soap',
#  'Pioneer sound system with Bluetooth and aux',
#  'Neutro body soap',
#  'Schneider oven',
#  'Pool table',
#  'JVC Soundbar sound system with Bluetooth and aux',
#  'lis',
#  'no name body soap',
#  '65\\" HDTV with Amazon Prime Vide',
#  'Bose Bluetooth sound system',
#  'Eurogas  stainless steel electric stove',
#  '24\\" TV with standard cable',
#  'Game console: Nintendo Switch and PS4',
#  'sony sound system',
#  'Ancient Earth body soap',
#  'Garnier-Thiebaut linens',
#  'Loreal .... conditioner',
#  'Petit marseillais  body soap',
#  '49\\" HDTV with Netfli',
#  'Head and Shoulder 2 in 1 shampoo',
#  '124\\" HDTV with Netfli',
#  'AESOPS body soap',
#  'Clean body soap',
#  'irish sprin',
#  'Fisher & Paykel induction stove',
#  'lectric oven oven',
#  '50\\" HDTV with Rok',
#  'electrica stainless steel electric stove',
#  '28\\" HDTV with standard cabl',
#  'Falcon gas stove',
#  'Ikea stainless steel oven',
#  'Electrolux stainless steel induction stove',
#  'Very cold refrigerator',
#  'Continental breakfast available \\u2014 $13 per person per day',
#  'Gym in building',
#  'Port\\u00e1til  electric stove',
#  'Tommy Bahama conditioner',
#  'Paid parking lot off premises \\u2013 TRY25 per day',
#  'irplay and USB sound system with Bluetooth and aux',
#  'Bosch electric stove',
#  '49\\" HDTV with Netflix',
#  'om pequeno congelador acoplado refrigerator',
#  'inist\\u00e9rio do Desenvolvimento Agr\\u00e1rio e SEBRAE.  shampoo',
#  'Paid parking lot on premises \\u2013 MXN60 per da',
#  'Dining area for 14 people',
#  'Teka electric stove',
#  '120\\" HDTV with Netfli',
#  'Hisence refrigerator',
#  'Wifi \\u2013 1515 Mbps',
#  'Shared outdoor infinity saltwater pool',
#  'supplied on arrival only shampoo',
#  'cooktop \\u00e0 g\\u00e1s gas stove',
#  'variada body soap',
#  'Shower bathtub combo',
#  '32\\" HDTV with Chromecas',
#  'Wifi \\u2013 56 Mbps',
#  "L'erbolario ginepro nero body soap",
#  'Building staff',
#  'Dove ou similar shampoo',
#  'Brastemp side by side refrigerator',
#  'Continental stainless steel gas stove',
#  'Geneva Lab Model S sound system with aux',
#  'Paid street parking off premises \\u2013 EUR35 per day',
#  'Refrigerador Frost Free Duplex Electrolux refrigerator',
#  'Paid parking garage off premises \\u2013 EUR30 per day',
#  'Extra pillows and blankets',
#  'Onsite bar \\u2014 Crown Shy',
#  'Blanko stainless steel gas stove',
#  'DeLonghi stainless steel gas stove',
#  'Bath & Body Works shampoo',
#  '42\\" HDTV with premium cabl',
#  'Complimentary hot breakfast',
#  'Paid parking garage off premises \\u2013 EUR24 per day',
#  'Regular. conditioner',
#  'Mitsubishi refrigerator',
#  'Le Labo toiletries',
#  'A\\u00e7elik refrigerator',
#  'tramontina gas stove',
#  'Lock on bedroom door',
#  'Puracy natural plant based body soap',
#  'LG smart Tech refrigerator',
#  'Samsung sound system with Bluetooth and aux',
#  'Free parking on premises \\u2013 5 spaces',
#  'T.TAIO Esponjab\\u00f3n body soap',
#  '32\\" HDTV with Chromecast',
#  'Wifi \\u2013 48 Mbps',
#  'Yves Rocher conditioner',
#  'the best body soap',
#  'A la reception refrigerator',
#  'on Aceite de Coco y C\\u00farcuma. shampoo',
#  'Dove pink bath bar body soap',
#  'Pack \\u2019n Play/travel crib',
#  'smeg stainless steel gas stove',
#  'face&body bar Bergman Kelly body soap',
#  'Samsung with water tap unit outside refrigerator',
#  'r. Bronners body soap',
#  'Thank you conditioner',
#  'Pergola',
#  'Leibherr refrigerator',
#  'Efes refrigerator',
#  '40\\" TV with Netfli',
#  'Gliss shampoo',
#  'Euro Gas stainless steel gas stove',
#  'Game console: PS5 and Xbox 360',
#  'Self check-in',
#  'Gated community',
#  'Free parking garage on premises \\u2013 5 spaces',
#  'Free parking garage on premises \\u2013 807 spaces',
#  'Airport shuttle',
#  'Continental breakfast available \\u2014 \\u20ac9 per person per day',
#  'Head & Shoulder shampoo',
#  '55\\" HDTV with premium cable',
#  'Paid parking lot off premises \\u2013 EUR3 per day',
#  'lendax or pantene conditioner',
#  'Pantane (all in one) shampoo',
#  'neutro  body soap',
#  'BEKO stainless steel oven',
#  'Dur',
#  'MITSUBISHI refrigerator',
#  '49\\" TV',
#  'Paid parking garage off premises \\u2013 EUR10 per hour',
#  'Provided by The Taj body soap',
#  '47\\" HDTV',
#  'Frigidaire refrigerator',
#  'Charlotte Rhys  body soap',
#  'Espresso machine',
#  '20\\" TV',
#  'Shared indoor lap pool',
#  'Mosquito net',
#  'Limited housekeeping \\u2014 weekly',
#  'Bose sound system with Bluetooth and aux',
#  'House bikes',
#  '2 burner induction cooktop.  We provide pots and pans. induction stove',
#  'Ar condicionado de janela em todos os quartos conditioner',
#  'LOREAL conditioner',
#  'Glow Lab conditioner',
#  'Phebo liquido body soap',
#  'Provided by The Taj conditioner',
#  '22\\" TV with standard cable',
#  'inside the room and in the living room refrigerator',
#  'Free washer\\u2013In unit',
#  'Gorenge Retro style refrigerator',
#  'OX shampoo',
#  'Arcelik gas stove',
#  'Whirlpool oven',
#  "L'OCCITANE shampoo",
#  '50\\" TV with Netfli',
#  'consul stainless steel oven',
#  'Fridge and freezer combo refrigerator',
#  'Free residential garage on premises \\u2013 3 spaces',
#  'PHILLIPS Bluetooth sound system',
#  ' bocas stainless steel gas stove',
#  'Paid valet parking on premises \\u2013 $100 per da',
#  'Pineware stainless steel electric stove',
#  'Consul Duplex Frost Free refrigerator',
#  'candy refrigerator',
#  '46\\" HDTV',
#  'occitaine conditioner',
#  'granado shampoo',
#  'Salton mini kitchen oven',
#  'Onsite restaurant \\u2014 de Sers Restaurant',
#  '42\\" HDTV with Chromecas',
#  'different brands at different times body soap',
#  'alexa sound system',
#  'Bluetooth sound system',
#  'four combin\\u00e9 micro onde gril four chaleur tournante oven',
#  'Dov',
#  'ma porta com geladeira e freezer integrados refrigerator',
#  'Dedicated workspace: desk and table',
#  'Full size General Electric refrigerator',
#  'Essentials',
#  'Officine del Mugello (vegan ok) shampoo',
#  'Nightclub',
#  ' g\\u00e1s. oven',
#  '60\\" HDTV',
#  'Outdoor seating',
#  '42\\" TV with Netfli',
#  'Onsite restaurant \\u2014 Crown Shy',
#  "Onsite bar \\u2014 S'Bar",
#  'Central heating',
#  'franke stainless steel oven',
#  'bosh refrigerator',
#  'Paid parking on premises \\u2013 3 spaces',
#  'Charcoal barbeque',
#  'Consul du',
#  'Tresemme conditioner',
#  'Ethernet connection',
#  'Blu-Ray player',
#  '24-hour fitness center',
#  'Self-parking \\u2014 \\u20ac34/stay',
#  'Shared fenced garden or backyard',
#  'Acca Kappa body soap',
#  'HAMILTON BEACH stainless steel oven',
#  'Vestel refrigerator',
#  'Fog\\u00e3o \\u00e0 g\\u00e1s de 4 bocas gas stove',
#  'Dining area for 10 people',
#  'Kayaks',
#  'Shared indoor heated pool',
#  '55\\" HDTV with Rok',
#  'INDUSTRIAL refrigerator',
#  'Induction plate induction stove',
#  'Bang & Olufson sound system',
#  'Pioneer Bluetooth sound system',
#  'Clothing storage: walk-in closet',
#  'DVD player',
#  'Changing table',
#  'Wifi \\u2013 135 Mbps',
#  'Clothing storage: wardrobe and closet',
#  'Wifi \\u2013 71 Mbps',
#  'JukeBox Bluetooth sound system',
#  'Wifi \\u2013 29 Mbps',
#  'Lirio body soap',
#  '\\u00c1rgan oil of Morocco shampoo',
#  'Game console: Xbox 360',
#  'sans d\\u00e9conner ? conditioner',
#  'Green Te',
#  'Duplex - frost free refrigerator',
#  'WIRPOOL refrigerator',
#  '49\\" HDTV with Amazon Prime Vide',
#  'variadas conditioner',
#  'Lavarino shampoo',
#  'bosh oven',
#  'Gas fireplace',
#  'Organics conditioner',
#  'Candy stainless steel oven',
#  'Ariston stainless steel gas stove',
#  '32\\" TV with premium cable',
#  '30\\" HDTV with Netfli',
#  'It varies conditioner',
#  'Cooked-to-order breakfast available \\u2014 $15 per person per day',
#  '04 bocas c/forno gas stove',
#  'DENON Bluetooth sound system',
#  'Combin\\u00e9 four et micro-ondes Whirlpool oven',
#  'Paid parking lot on premises \\u2013 1 space',
#  'Subzero refrigerator',
#  'Paid street parking off premises \\u2013 EUR10 per day',
#  '50\\" HDTV with Chromecas',
#  'Air conditioning',
#  'Free parking garage on premises \\u2013 600 spaces',
#  'sach\\u00eas body soap',
#  'AFRICOLOGY conditioner',
#  'MABE stainless steel oven',
#  'Elevator',
#  '5.1 Surround Sound Bluetooth sound system',
#  'Free wifi',
#  '74\\" HDTV with Chromecast',
#  '32\\" HDTV with Netflix',
#  'Sabonete de Erva Doce  body soap',
#  'Wifi \\u2013 950 Mbps',
#  'Meditation room',
#  'Bosch - Electric oven oven',
#  'Samsung stainless steel gas stove',
#  'HDTV with Apple T',
#  'nd wardrobe',
#  'forninho el\\u00e9trico oven',
#  '116\\" HDTV with Netfli',
#  'Bvlgari shampoo',
#  'Heating',
#  '40\\" HDTV with Chromecast',
#  'Altus refrigerator',
#  'Biologico body soap',
#  'Wine cooler',
#  'Mabe. Capacity 93L refrigerator',
#  'Wifi \\u2013 16 Mbps',
#  'Garnier shampoo',
#  'LaBottega shampoo',
#  'Puracy or Jr Watkins body soap',
#  'Kumtel stainless steel electric stove',
#  'Gazebo',
#  'Smeg induction stove',
#  'sabonete liquido body soap',
#  'Free carport on premises',
#  'Suave shampoo',
#  'Bathroom essentials',
#  'LG sound system',
#  'Free carport on premises \\u2013 3 spaces',
#  'Ancient Earth conditioner',
#  'Denon sound system with Bluetooth and aux',
#  '02 bocas c/forno gas stove',
#  'Paid parking garage on premises \\u2013 30 spaces',
#  '82\\" HDTV',
#  'Gas stove smeg oven',
#  'Mini Stove with 2 hot plates and small oven electric stove',
#  'MIlton Brown body soap',
#  'HDTV with Apple TV',
#  'Elidor conditioner',
#  'Occitane conditioner',
#  'vestel refrigerator',
#  'Wifi',
#  'Dedicated workspace: desk and office chair',
#  'Pentene body soap',
#  'Bose SoundTouch 30 Bluetooth sound system',
#  'Private outdoor heated saltwater pool',
#  'sony sound system with Bluetooth and aux',
#  'Onsite restaurant \\u2014 Niwa Bistro Cafe',
#  'Echo Dot Bluetooth sound system',
#  '165\\" HDTV with Netfli',
#  'Marca stainless steel gas stove',
#  'Am\\u00e9ricain refrigerator',
#  'Onsite bar \\u2014 Les Dames',
#  'real soap from Aleppo body soap',
#  'Acompanha o fogao oven',
#  'Free parking garage on premises \\u2013 3 spaces',
#  ' Electrolux stainless steel gas stove',
#  'kalvinator gas stove',
#  'ikea stainless steel oven',
#  'Provided by The Taj  shampoo',
#  'Bosch  stainless steel oven',
#  'Denon Amplifier sound system with Bluetooth and aux',
#  'cheap one body soap',
#  'Defy stainless steel oven',
#  'Cussons Oatmeal body soap',
#  'Lake access',
#  '30\\" TV with Netflix',
#  'Cooktop  5 bocas Brastemp gas stove',
#  'Triad sound system',
#  'BRANDT refrigerator',
#  'Onsite restaurant \\u2014 Sapori Dal Mondo Restaurant',
#  'guest soap body soap',
#  'Hitachi refrigerator',
#  'hotelin markas\\u0131 shampoo',
#  'Kic refrigerator',
#  'Fischer Cooktop 2 bocas gas stove',
#  'Zeytuni (Olive Oil) shampoo',
#  'Onsite rooftop bar \\u2014 Bar ',
#  'samsung stainless steel oven',
#  'teka stainless steel electric stove',
#  'hower gel and sbampoo is Dove body soap',
#  '43\\" TV',
#  'basico stainless steel oven',
#  'Triangle / Onkyo sound system with Bluetooth and aux',
#  'O xampu j\\u00e1 \\u00e9 com condicionador. conditioner',
#  'Cooktop 4 queimadores sem forno gas stove',
#  'Free driveway parking on premises \\u2013 2 spaces',
#  'Glyco-Lemon most of the time. It changes. shampoo',
#  'Nioxin  shampoo',
#  'Minibar',
#  'Hunter - Made naturally in Melbourne shampoo',
#  'hromecast audi',
#  'Consul refrigerator',
#  'Dop or le petit marseillais shampoo',
#  'Liebherr + petit cong\\u00e9lateur refrigerator',
#  'Soapbox body soap',
#  'Ar\\u00e7elik oven',
#  'Shower gel',
#  'Paid parking garage off premises',
#  'Security system',
#  'Consul 280L refrigerator',
#  '64\\" HDTV with Apple T',
#  'dove conditioner',
#  'Org\\u00e1nico shampoo',
#  'Valet parking available for a fee',
#  'BOSE sound system',
#  'rosiere stainless steel oven',
#  'Viking gas stove',
#  'Thankyou body soap',
#  'eletrolux frost free refrigerator',
#  'La cocina est\\u00e1 dise\\u00f1ada para hacer platillos sencillo',
#  'solo su richiesta shampoo',
#  'Sukrin conditioner',
#  'Leif conditioner',
#  'AEG COMBI CONVECTION MICROWAVE stainless steel oven',
#  'Wifi \\u2013 1000 Mbps',
#  'Laptop-friendly workspace',
#  'Amenidad peque\\u00f1a por estancia body soap',
#  'frigobar refrigerator',
#  'First Line refrigerator',
#  'Children\\u2019s books and toys for ages 5-10 years old and 10+ years old',
#  'TV Samsung sound system with Bluetooth and aux',
#  'Portable hotplate electric stove',
#  'variada conditioner',
#  'Omnisens conditioner',
#  'ChiQ refrigerator',
#  'rebul shampoo',
#  'Free parking garage on premises \\u2013 2 spaces',
#  'GE Frost Free refrigerator',
#  'Local conditioner',
#  'Stainless steel gas stove',
#  'Natural Living shampoo',
#  'Balcony',
#  'Wifi \\u2013 10030 Mbps',
#  'nd office chair',
#  'Housekeeping',
#  '37\\" HDTV with premium cable',
#  '51\\" HDTV',
#  'Induction stove',
#  'Hammock',
#  'Onsite bar \\u2014 Clinton Hall & Rooftop Beer Garden',
#  'brastemp cook top gas stove',
#  '46\\" HDTV with premium cabl',
#  'Pool house',
#  'Paid parking garage off premises \\u2013 $50 per day',
#  'Xampu shampoo',
#  'remium cabl',
#  'Cleaning before checkout',
#  'SamSung refrigerator',
#  'Onsite bar \\u2014 Bel Ami Bar',
#  'Geral gas stove',
#  'Westinghouse stainless steel oven',
#  '36\\" TV',
#  'brasntemp refrigerator',
#  'Mini four oven',
#  'Paid parking garage on premises \\u2013 EUR10 per da',
#  'Shared outdoor infinity rooftop pool',
#  'Electrolux  stainless steel gas stove',
#  'Dispenser for shampoo & bodywash in shower shampoo',
#  '25\\" TV with Chromecast',
#  'lidor or pantene body soap',
#  'Q3 Bluetooth sound system',
#  'AESOP shampoo',
#  'Shared outdoor heated rooftop pool',
#  'oderno apartamento com WIFI conditioner',
#  'Whirlpool stainless steel gas stove',
#  'OMEGA stainless steel gas stove',
#  'Forno do fog\\u00e3o oven',
#  'London Fine Soaps shampoo',
#  'Airplay sound system',
#  'Smeg electric stove',
#  'Lampada Speaker Bluetooth sound system',
#  'Appelles toiletries',
#  'Artusi refrigerator',
#  'Game console: PS3',
#  'Computer',
#  'ORGANIC body soap',
#  'Eletrolux stainless steel gas stove',
#  'Mrs. Meyers body soap',
#  'various brands - liquid form body soap',
#  'Propia body soap',
#  'Sukin or similar brand shampoo',
#  'SIEMENS  stainless steel gas stove',
#  'Sunlight body soap',
#  'Free residential garage on premises',
#  '45\\" HDTV with Amazon Prime Vide',
#  'Hunter - made naturally in Melbourn',
#  'ody wash and conditioner silicone free  conditioner',
#  'Free driveway parking on premises \\u2013 6 spaces',
#  'Puracy plant based and natural/JR watkins body soap',
#  'g\\u00e1s oven',
#  'Venax- 2 bocas.  gas stove',
#  'Beko Ofice type refrigerator',
#  'Organic Care conditioner',
#  'Clicks conditioner',
#  '137\\" HDTV with standard cable',
#  'Esmaltec gas stove',
#  'Onsite bar \\u2014 cloudM',
#  '75\\" HDTV with standard cable',
#  'Foosball table',
#  '41\\" HDTV with premium cable',
#  'Paid parking garage on premises \\u2013 BRL10 per da',
#  'Clothing storage: wardrobe and dresser',
#  'Nuxe toiletries',
#  'Sound Bar Bluetooth sound system',
#  'propia body soap',
#  'Elseve shampoo',
#  'Sonons sound system',
#  '40\\" TV with standard cable',
#  'BOSCH oven',
#  'Walita oven',
#  'Sono',
#  'HDTV with Chromecast',
#  'Granado conditioner',
#  'N\\u00e3o \\u00e9 um fog\\u00e3o \\u00e9 um fogareiro el\\u00e9trico electric stove',
#  'Beach essentials',
#  'fisherparker refrigerator',
#  'Smeg stainless steel stove',
#  'Clean conditioner',
#  'Standard electric stove',
#  'nivea body soap',
#  'Mini-Four oven',
#  'rexona liguido body soap',
#  'Parrila con dos hornillas stainless steel electric stove',
#  '153\\" HDTV with Amazon Prime Vide',
#  'Lavarino Cosso shampoo',
#  '43\\" HDTV with Amazon Prime Video',
#  'Alexa  Bluetooth sound system',
#  'Security monitors',
#  'Local body soap',
#  'Paid parking garage on premises \\u2013 AUD10 per da',
#  '38\\" TV with Netflix',
#  'Hi Sense refrigerator',
#  '107\\" HDTV with Amazon Prime Vide',
#  'Private living room',
#  'Mixed brands body soap',
#  'Brastemp refrigerator',
#  ' in 1. sound system with aux',
#  'neutro hipoalergenico body soap',
#  'Dryer',
#  'Saba refrigerator',
#  'A partager refrigerator',
#  'Sharp French Door with Freezer  refrigerator',
#  'Ar\\u00e7elik refrigerator',
#  'MABE stainless steel gas stove',
#  'Shampoo e Condicionador 2x1 Realgems - Capim Lim\\u00e3o shampoo',
#  'Whirlpool gas stove',
#  'Black and Decker stainless steel oven',
#  'Sonos via wifi sound system',
#  'CONSUL  360 LITROS refrigerator',
#  'Heated floor',
#  'occitane body soap',
#  '48\\" HDTV with standard cable',
#  'Bang & Olufsen Bluetooth sound system',
#  'Duru body soap',
#  'Projector',
#  'Miele  stainless steel gas stove',
#  'Paid valet parking on premises \\u2013 $25 per da',
#  'Yamaha Bluetooth sound system',
#  'hotel body soap',
#  'TV with standard cabl',
#  'JBL sound system with Bluetooth and aux',
#  'Onsite bar \\u2014 Restaurant Cantina',
#  'Paid valet parking on premises',
#  'Valet parking \\u2014 $40/day',
#  'Self-parking \\u2014 $51/day',
#  'Omnisens body soap',
#  'Organic Care  shampoo',
#  'LG Stove stainless steel electric stove',
#  'bio conditioner',
#  'H&S conditioner',
#  ' Amenities Realgem\\u2019s -Talentos do Brasil Feita a base de me',
#  'Brandt gas stove',
#  'Samsung refrigerator',
#  'Patio',
#  '2 fours: Micro-onde et chaleur tournante stainless steel oven',
#  'Eletrolix inox 2 portas refrigerator',
#  'Localizado no 3\\u00ba andar no ed\\u00edficio em frente com elevador. refrigerator',
#  '30\\" TV with standard cable',
#  'por wifi Bluetooth sound system',
#  'Sub Zero refrigerator',
#  'Outdoor parking',
#  'Bio La vie Claire shampoo',
#  'DeLonghi stainless steel oven',
#  '0 spaces',
#  'Officine del Mugello (vegan ok) body soap',
#  'Built-in sound system in the apartment. sound system',
#  'Lounge area',
#  'e hotelari',
#  'Flea Market Bluetooth sound system',
#  'Supplied on arrival only body soap',
#  'JVC sound system with Bluetooth and aux',
#  'Franke stainless steel gas stove',
#  'Whirlpool refrigerator',
#  'Children\\u2019s books and toys for ages 2-5 years old and 5-10 years old',
#  'Aesop conditioner',
#  'Savon bio body soap',
#  'arcelik oven',
#  'French Door Full Sized Fridge refrigerator',
#  'BOSE 700 Bluetooth sound system',
#  'Paid parking garage off premises \\u2013 EUR10 per day',
#  'Aspar Botanical Body Cleanser  body soap',
#  'Free toiletry samples. shampoo',
#  'Onsite bar \\u2014 Bar ',
#  'Micro onde oven',
#  '60\\" HDTV with Netfli',
#  'Electrolux stainless steel oven',
#  'Ikea oven microwave combo stainless steel oven',
#  'Shared sauna',
#  'KMS Salon grade conditioner',
#  'Mugler body soap',
#  'Clothing storage: dresser and wardrobe',
#  'SMEG stainless steel electric stove',
#  'Smeg stainless steel oven',
#  'Fire extinguisher',
#  '27\\" HDTV with standard cable',
#  'Molten Brown body soap',
#  'Bose bluetooth speaker Bluetooth sound system',
#  'Daewoo con congelador y agua purificada refrigerator',
#  'Paid parking garage on premises \\u2013 $15 per da',
#  "Chef's kitchen",
#  'Stainless Steel Fridgedare refrigerator',
#  'cooktop stainless steel gas stove',
#  'westinghouse refrigerator',
#  'Paid parking garage off premises \\u2013 $4 per day',
#  'Hangers',
#  'Sulphur free conditioner',
#  'BEKO refrigerator',
#  'firstline refrigerator',
#  'Clothing storage: walk-in closet and closet',
#  '32\\" HDTV with standard cable',
#  'Neutrogena Body Wash body soap',
#  'Whirpool stainless steel oven',
#  'Laundry services',
#  'Daewoo refrigerator',
#  'REBUL shampoo',
#  'Shared outdoor heated infinity pool',
#  '81\\" TV',
#  'Paid parking lot on premises \\u2013 EUR5 per day',
#  'Paid parking off premises',
#  'Wifi \\u2013 8 Mbps',
#  'Bio body soap',
#  'Yamaha sound system with aux',
#  'Beko stainless steel oven',
#  'local PA (see Photo) sound system with aux',
#  'lactovit body soap',
#  'Onsite bar',
#  '50\\" HDTV with Amazon Prime Vide',
#  'Natural body soap',
#  'Palmolive Milk and Honey body soap',
#  '34\\" HDTV with Netflix',
#  'Country Life body soap',
#  '143\\" HDTV with Chromecas',
#  'bosche stainless steel oven',
#  'Ultimate Ears Bluetooth Speaker sound system',
#  'Self-parking \\u2014 $50/stay',
#  'Natura TodoDia body soap',
#  'Paid parking garage on premises \\u2013 BRL50 per da',
#  'MISS LYNN conditioner',
#  'Paid washer\\u2013In unit',
#  '\\u0130pek shampoo',
#  'pantene shampoo',
#  'Breakfast available \\u2014 \\u20ac10 per person per day',
#  'kenwood sound system',
#  'Denon / Marshall sound system with Bluetooth and aux',
#  'rebul conditioner',
#  'Harman Kardon sound system with aux',
#  'Phillips refrigerator',
#  'dy wash and conditioner silicone free  shampoo',
#  'Paid parking garage on premises \\u2013 1 space',
#  'AMG oven',
#  'Bosh stainless steel oven',
#  '18\\" TV with standard cable',
#  'Dr Woods body soap',
#  'Johnson\\"s body soap',
#  'Onsite restaurant \\u2014 Azul on the Rooftop',
#  'Paid street parking off premises \\u2013 EUR4 per hour',
#  'En \\u00e1reas comunes refrigerator',
#  'Paid dryer\\u2013In building',
#  'hromecast',
#  'PANTENE conditioner',
#  'ELETROLUX stainless steel gas stove',
#  'Electrolux 300 litros refrigerator',
#  'Cree',
#  'Organic neutral body soap',
#  'UPNP / Air sound system with aux',
#  '52\\" HDTV',
#  'Westinghouse 370ltr refrigerator',
#  '\\u00c7etinta\\u015f stainless steel oven',
#  'Microwave',
#  '81\\" HDTV with Rok',
#  "ohnson'",
#  'Aesop  conditioner',
#  'Thomson avec partie cong\\u00e9lateur. refrigerator',
#  '45\\" HDTV with premium cable',
#  'Defy electric stove',
#  'Convection microwave oven',
#  'buklet body soap',
#  'Haier 222l refrigerator',
#  'Bosch Electric Oven stainless steel oven',
#  'lg refrigerator',
#  'Consul stainless steel oven',
#  'vocina sound system with Bluetooth and aux',
#  'it varies body soap',
#  'S\\u0130EMENS refrigerator',
#  'Heated infinity pool',
#  'Whirlpool stainless steel induction stove',
#  'Biodegradabl',
#  'Clothing storage: walk-in closet and dresser',
#  'Record player',
#  'BRASTEMP refrigerator',
#  '81\\" TV with Roku',
#  'Coslys body soap',
#  'Pizza oven',
#  'WOOLWORTHS body soap',
#  'Parking',
#  '.. conditioner',
#  'Sam Sung refrigerator',
#  'Fragonard toiletries',
#  'large Samsung frige will a sperate frezer  refrigerator',
#  'mazon Prime Vide',
#  'fischer and Pykel refrigerator',
#  'Free carport on premises \\u2013 2 spaces',
#  'bosch stainless steel oven',
#  '32\\" HDTV with premium cable',
#  'fresh & clean disinfected shampoo',
#  'Luxury Brand  conditioner',
#  'Molton Brown body soap',
#  'odelo Yamaha HS5 sound system with aux',
#  'Puracy plant based and natural body soap',
#  'WHIRPOOL refrigerator',
#  'Brastemp Frost-free 480 l com bebedouro na porta refrigerator',
#  'Fountain',
#  'Fisher and Paykel refrigerator',
#  'Paid parking garage off premises \\u2013 BRL15 per hour',
#  'cortana Bluetooth sound system',
#  'DIAL body soap',
#  'Brastemp stainless steel oven',
#  'bertazonni stainless steel oven',
#  'Aro shampoo',
#  'Complimentary breakfast buffet',
#  'Dining table',
#  'Platinum induction stove',
#  'Clothing storage: wardrobe and walk-in closet',
#  'General Electric induction stove',
#  'Dial body soap',
#  'Paid parking garage on premises \\u2013 EUR15 per da',
#  '39\\" HDTV with standard cable',
#  'Sabonete l\\u00edquido na pia do banheiro body soap',
#  '32\\" HDTV',
#  'ound system with Bluetooth and aux',
#  'Chef oven',
#  'mazon Prime Video',
#  'Paid parking lot on premises \\u2013 AUD30 per da',
#  'Dedicated workspace: table and office chair',
#  'Bosch oven and gas hob stainless steel oven',
#  'Sukrin body soap',
#  'Ice machine',
#  '28\\" HDTV',
#  'Yamaha sound system with Bluetooth and aux',
#  'local body soap',
#  'Codage toiletries',
#  'phebo /dove/ body soap',
#  'Davell stainless steel gas stove',
#  'Diverso shampoo',
#  'Deixamos um mini-sabonete Calgar',
#  'KIRKLAND refrigerator',
#  'Outdoor saltwater pool',
#  'Pantene pro-',
#  'BOSCH induction stove',
#  'Paid street parking off premises \\u2013 BRL6 per day',
#  'Stove',
#  'Aspar conditioner',
#  'Window AC unit',
#  'Libre conditioner',
#  'Paid parking lot on premises \\u2013 EUR10 per da',
#  'starter set only shampoo',
#  'Clothing storage: close',
#  'Member Mark. Sams conditioner',
#  'Bluetooth speaker',
#  'per mani/viso/doccia body soap',
#  'Frigedare stainless steel oven',
#  'Shared outdoor pool',
#  'Washer',
#  'Wifi \\u2013 800 Mbps',
#  'Radox body soap',
#  'Frigobar dentro quarto refrigerator',
#  'S/M shampoo',
#  'TOSHIBA refrigerator',
#  'Top plate induction induction stove',
#  'our product shampoo',
#  'Westinghouse french door refrigerator',
#  'Paid parking lot on premises \\u2013 EUR7 per da',
#  'natural liquid body wash body soap',
#  'Dedicated workspace: office chair and table',
#  'Integrated refrigerator',
#  'sonos Bluetooth sound system',
#  'Bosch stainless steel induction stove',
#  'Phillips sound system with aux',
#  'Whirlpool  stainless steel gas stove',
#  'Paid parking garage off premises \\u2013 EUR3 per day',
#  'Undercounter fridge refrigerator',
#  'GE PROFILE refrigerator',
#  'Thank You brand body soap',
#  'yves rocher body soap',
#  'VESTEL refrigerator',
#  'Children\\u2019s books and toys for ages 2-5 years old',
#  'Free driveway parking on premises \\u2013 1 space',
#  'Fog\\u00e3o com forno oven',
#  'Alfresco shower',
#  'AEG Glass 5 plate electric stove',
#  'Wifi \\u2013 75 Mbps',
#  'Vegan S\\u0131v\\u0131 Sabun  body soap',
#  'Toaster',
#  'CocktailAudio X30 InStyle Speakers sound system with aux',
#  'bosch oven',
#  "L' Occitane body soap",
#  'La Petite body soap',
#  'Paid parking lot off premises \\u2013 $4 per day',
#  'Stand up paddle board',
#  '60\\" HDTV with standard cable',
#  'UeBoom Bluetooth sound system',
#  'Due ripiani  refrigerator',
#  'Paid parking garage on premises \\u2013 EUR20 per da',
#  'Pioneer sound system with aux',
#  '132\\" HDTV with standard cabl',
#  'no frills brand body soap',
#  'petit marseillais bio body soap',
#  'DOVE OU N\\u00cdVEA ( NOVOS ) body soap',
#  'Natura Ekos toiletries',
#  'Sabonete body soap',
#  'Continental breakfast available \\u2014 \\u0e3f270 per person per day',
#  '? body soap',
#  'TRESemm\\u00e9 shampoo',
#  '40\\" TV with Roku',
#  'Bosch gas stove',
#  'Liebherr refrigerator',
#  'Lavarino Cosso body soap',
#  'variadas shampoo',
#  '42\\" HDTV',
#  'Consul 280 L refrigerator',
#  'Enceinte Bose  Bluetooth sound system',
#  'Samsung sound system',
#  'Paid parking lot off premises \\u2013 TRY35 per day',
#  '43\\" HDTV with Amazon Prime Vide',
#  '65\\" HDTV with Chromecas',
#  'Free parking on premises \\u2013 1 space',
#  'abl',
#  'rascos recicl\\u00e1veis e extratos adquiridos de pequenos agricultores brasileiros. Al\\u00e9m dos extratos da agricultura familia',
#  'GBC Bluetooth sound system',
#  'Tres Seme shampoo',
#  'Lavanda body soap',
#  'Defy  Hob stainless steel gas stove',
#  'Wifi \\u2013 125 Mbps',
#  'ivea ou similar body soap',
#  'sabonete em barr',
#  '50\\" HDTV with premium cabl',
#  'Aesop body soap',
#  'Free parking on premises \\u2013 3 spaces',
#  'GE refrigerator',
#  'Paid parking lot off premises \\u2013 BRL40 per day',
#  'Acca Kappa shampoo',
#  'Defy (Electric) stainless steel oven',
#  'Cooktop 4 bocas Brastemp gas stove',
#  'Palmolive and organic conditioner',
#  'Paid street parking off premises \\u2013 AUD8 per hour',
#  'Brastemp stainless steel gas stove',
#  'Brastemp oven',
#  'Patio or balcony',
#  'Hot water kettle',
#  '5 amazon alexa  Bluetooth sound system',
#  '50\\" TV with premium cable',
#  'WHIRLPOOL gas stove',
#  'Cooktop gas stove',
#  'Siemens  stainless steel oven',
#  '50\\" HDTV with Netflix',
#  'MITSUBISI refrigerator',
#  'Treseme shampoo',
#  'Ariston stainless steel oven',
#  'SIEMENS stainless steel oven',
#  'Wifi \\u2013 150 Mbps',
#  '1 fornello funzionante induction stove',
#  '48\\" HDTV with Netfli',
#  'electrolux stainless steel oven',
#  '82\\" HDTV with Netfli',
#  'Head and Shoulders conditioner',
#  'Consul frost free refrigerator',
#  'Miss Lynn conditioner',
#  'siemens stainless steel oven',
#  'Wifi \\u2013 22 Mbps',
#  'Miele stainless steel gas stove',
#  'Pool toys',
#  'DOVE Nutritive Secrets shampoo',
#  '120\\" TV with Netfli',
#  'Elseve Loreal conditioner',
#  'Head and shoulders shampoo',
#  'Dove            Nutritive Secrets shampoo',
#  'Clothing storage: dresser and closet',
#  'Paid parking lot on premises',
#  'ustralia. conditioner',
#  'Central conditioner',
#  'Whirlpool for Ikea refrigerator',
#  'Philco stainless steel oven',
#  'TV',
#  'L\\u2019Occitane en Provence body soap',
#  'atmeal + Coconut brands. body soap',
#  'Bosch stainless steel oven',
#  'Paid parking lot on premises \\u2013 ZAR80 per day',
#  'Lux (l\\u00edquido)  body soap',
#  'Sun loungers',
#  'Ancient Earth shampoo',
#  'Dr. Bronner All in one body soap',
#  '95\\" HDTV',
#  'Kenwood sound system',
#  'elidor blendax or pantene shampoo',
#  'harman carbon  sound system',
#  'Bvlgari body soap',
#  'Bath & Body Works conditioner',
#  'HDTV with Rok',
#  'Portable Induction 1 pot stove induction stove',
#  'White-Wesinghouse refrigerator',
#  '42\\" HDTV with Netflix',
#  'Electrolux induction stove',
#  'MAC Bluetooth sound system',
#  'Onsite rooftop bar \\u2014 Rooftop Sky Stars Bar',
#  "ohnson's body soap",
#  'tandard cable',
#  'GE stove',
#  'single hob plate  stove',
#  'Dr. Bronner All in one  shampoo',
#  'consul frosfree refrigerator',
#  'Frigo SMEG ; freezer refrigerator',
#  'Private outdoor lap pool',
#  'lux body soap',
#  'ORGANIC conditioner',
#  'PinoSilvestre body soap',
#  'iss Lynn. body soap',
#  'Technika single burner electric stove',
#  'Smoking parlor',
#  'Paid parking garage off premises \\u2013 EUR27 per day',
#  'Paid parking lot on premises \\u2013 MXN200 per day',
#  'Hitachi stainless steel oven',
#  'Paid parking garage on premises \\u2013 EUR8 per da',
#  'AIRPLAY sound system',
#  'Smart home technology',
#  "Trader Joe's shampoo",
#  'L\\u2019Or\\u00e9al  conditioner',
#  'o probado en animales. body soap',
#  'MONSAVON body soap',
#  'eletrolux stainless steel gas stove',
#  'Beko gas stove',
#  ...}

# %%
unique_values1= pd.DataFrame(list(unique_values))

# %%
unique_values1.to_excel('unique_values.xlsx')

# %% [markdown]
# # Count how many times each unique value

# %%
#créer table avec les valeurs uniques et le compte de ces valeurs 
count=amenities.apply(pd.value_counts)

# %%
#insérer la colonne sum_count et additioner les valeurs 
count.insert(loc=0, column='sum_count', value=count.sum(axis=1))

# %%
#trier les valeurs du plus grand au plus petit
count.sort_values("sum_count", axis = 0, ascending = False,
                 inplace = True, na_position ='last')

# %%
#display the most recurent
count2=count["sum_count"]
count2.head(10)
# Out:
# Wifi                       260090.0
# Essentials                 253532.0
# Long term stays allowed    241054.0
# Kitchen                    240923.0
# TV                         213037.0
#                              ...
# Safe                         1559.0
# Full kitchen                 1514.0
# Private living room          1498.0
# Fireplace guards             1460.0
# Outdoor furniture            1390.0
# Name: sum_count, Length: 100, dtype: float64

# %% [markdown]
# # Add Primary Key

# %%
#add Listing_id
amenities.insert(loc=0, column='Listing_id', value=all_data["listing_id"])
amenities.head(1)
# Out:
#    Listing_id        0        1       2     3                        4     5  \
# 0      281420  Heating  Kitchen  Washer  Wifi  Long term stays allowed  None
#
#       6     7     8  ...    79    80    81    82    83    84    85    86  \
# 0  None  None  None  ...  None  None  None  None  None  None  None  None
#
#      87    88
# 0  None  None
#
# [1 rows x 90 columns]

# %%
#create excel doc
amenities.to_excel('Amenities.xlsx')
